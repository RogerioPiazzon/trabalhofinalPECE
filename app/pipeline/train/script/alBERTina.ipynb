# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import pandas as pd
from sklearn.metrics import confusion_matrix,f1_score,classification_report
import numpy as np
import re,unicodedata,nltk
from transformers import AutoTokenizer, TFDebertaV2ForSequenceClassification, BertConfig
import keras
import pickle

# gpus = tf.config.list_physical_devices("GPU")
# if gpus:
#     for gpu in gpus:
#         print("Found a GPU with the name:", gpu)
# else:
#     print("Failed to detect a GPU.")

# %%
with open('/content/drive/MyDrive/PECE/models/dataset_train_test/dataset_dict.pickle', 'rb') as file:
    dataset_dict = pickle.load(file)

num_classes = dataset_dict['n_class']

# %%
model_id = 'PORTULAN/albertina-900m-portuguese-ptbr-encoder-brwac'
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = TFDebertaV2ForSequenceClassification.from_pretrained(model_id,num_labels=num_classes,num_hidden_layers=12,hidden_dropout_prob=0.4)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/379 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.45M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/8.64M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/952 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.77G [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFDebertaV2ForSequenceClassification: ['deberta.encoder.layer.23.intermediate.dense.bias', 'deberta.encoder.layer.21.attention.self.value_proj.weight', 'deberta.encoder.layer.23.attention.self.key_proj.bias', 'deberta.encoder.layer.22.attention.self.key_proj.bias', 'deberta.encoder.layer.15.attention.output.LayerNorm.weight', 'deberta.encoder.layer.20.attention.output.LayerNorm.bias', 'deberta.encoder.layer.21.output.LayerNorm.bias', 'deberta.encoder.layer.13.attention.output.LayerNorm.weight', 'deberta.encoder.layer.13.attention.self.key_proj.weight', 'deberta.encoder.layer.22.output.dense.weight', 'deberta.encoder.layer.19.attention.self.query_proj.weight', 'deberta.encoder.layer.17.attention.self.key_proj.bias', 'deberta.encoder.layer.17.attention.self.value_proj.bias', 'deberta.encoder.layer.18.attention.output.dense.weight', 'deberta.encoder.layer.14.attention.output.LayerNorm.bias', 'deberta.encoder.layer.20.attention.self.value_proj.weight', 'deberta.encoder.layer.17.output.dense.bias', 'deberta.encoder.layer.12.attention.output.LayerNorm.weight', 'deberta.encoder.layer.23.attention.self.value_proj.weight', 'deberta.encoder.layer.19.output.LayerNorm.weight', 'deberta.encoder.layer.15.attention.self.key_proj.bias', 'deberta.encoder.layer.19.attention.self.key_proj.weight', 'deberta.encoder.layer.16.attention.self.query_proj.weight', 'deberta.encoder.layer.19.output.dense.weight', 'deberta.encoder.layer.14.attention.self.key_proj.bias', 'deberta.encoder.layer.23.output.LayerNorm.bias', 'deberta.encoder.layer.12.output.dense.bias', 'deberta.encoder.layer.21.output.LayerNorm.weight', 'deberta.encoder.layer.21.intermediate.dense.weight', 'deberta.encoder.layer.20.attention.self.value_proj.bias', 'deberta.encoder.layer.12.intermediate.dense.weight', 'deberta.encoder.layer.14.attention.output.dense.weight', 'deberta.encoder.layer.19.attention.output.dense.bias', 'deberta.encoder.layer.22.attention.output.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'deberta.encoder.layer.16.attention.self.query_proj.bias', 'deberta.encoder.layer.20.intermediate.dense.bias', 'deberta.encoder.layer.13.attention.output.dense.weight', 'deberta.encoder.layer.19.output.dense.bias', 'deberta.encoder.layer.14.output.dense.weight', 'deberta.encoder.layer.14.output.dense.bias', 'deberta.encoder.layer.13.attention.self.query_proj.bias', 'deberta.encoder.layer.13.output.dense.bias', 'deberta.encoder.layer.18.output.dense.weight', 'deberta.encoder.layer.23.attention.self.key_proj.weight', 'deberta.encoder.layer.22.output.dense.bias', 'deberta.encoder.layer.18.attention.self.query_proj.bias', 'deberta.encoder.layer.17.attention.self.value_proj.weight', 'deberta.encoder.layer.21.attention.self.value_proj.bias', 'deberta.encoder.layer.16.attention.output.dense.weight', 'deberta.encoder.layer.15.attention.self.query_proj.bias', 'deberta.encoder.layer.16.attention.self.key_proj.weight', 'deberta.encoder.layer.18.output.dense.bias', 'deberta.encoder.layer.20.attention.self.key_proj.bias', 'deberta.encoder.layer.23.intermediate.dense.weight', 'deberta.encoder.layer.15.attention.output.LayerNorm.bias', 'deberta.encoder.layer.15.attention.self.value_proj.bias', 'deberta.encoder.layer.22.attention.self.value_proj.bias', 'deberta.encoder.layer.21.attention.output.dense.weight', 'deberta.encoder.layer.12.attention.self.key_proj.bias', 'deberta.encoder.layer.12.output.LayerNorm.weight', 'deberta.encoder.layer.21.output.dense.weight', 'deberta.encoder.layer.20.output.dense.weight', 'deberta.encoder.layer.23.attention.output.dense.weight', 'deberta.encoder.layer.14.intermediate.dense.weight', 'deberta.encoder.layer.19.attention.self.value_proj.weight', 'deberta.encoder.layer.23.output.dense.bias', 'deberta.encoder.layer.15.output.LayerNorm.bias', 'deberta.encoder.layer.17.output.LayerNorm.weight', 'deberta.encoder.layer.20.intermediate.dense.weight', 'deberta.encoder.layer.14 ...
# - This IS expected if you are initializing TFDebertaV2ForSequenceClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDebertaV2ForSequenceClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFDebertaV2ForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['pooler.dense.weight', 'pooler.dense.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def applytokenizer(sentences):
  input_ids=[]
  attention_masks=[]

  for sent in sentences:
      bert_inp=tokenizer.encode_plus(sent,add_special_tokens = True,max_length = 64, padding='max_length',return_attention_mask = True)
      input_ids.append(bert_inp['input_ids'])
      attention_masks.append(bert_inp['attention_mask'])

  input_ids=np.asarray(input_ids)
  attention_masks=np.array(attention_masks)
  return [input_ids,attention_masks]

# %%
X_train = applytokenizer(dataset_dict['X_train'])
X_test = applytokenizer(dataset_dict['X_test'])
y_train = np.asarray(dataset_dict['y_train'])
y_test = np.asarray(dataset_dict['y_test'])

# %%
log_dir='/content/drive/MyDrive/PECE/tensorboard_data/tb_albertina_v4'
model_save_path='/content/drive/MyDrive/PECE/models/albertina_model_v4.h5'

callbacks = [
             keras.callbacks.ModelCheckpoint(filepath=model_save_path,save_weights_only=True,monitor='val_loss',mode='min',save_best_only=True),
             keras.callbacks.TensorBoard(log_dir=log_dir),
             keras.callbacks.EarlyStopping(monitor="val_loss",min_delta=0.01,patience=50,verbose=0,mode="min")
             ]

print('\nalBERTina Model',model.summary())

loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
metric = tf.keras.metrics.SparseCategoricalAccuracy('accuracy')
optimizer = tf.keras.optimizers.Adam(learning_rate=2e-5,epsilon=1e-08)

model.compile(loss=loss,optimizer=optimizer,metrics=[metric])
# Out:
# Model: "tf_deberta_v2_for_sequence_classification"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  deberta (TFDebertaV2MainLa  multiple                  544614912
#  yer)
#
#  pooler (TFDebertaV2Context  multiple                  2360832
#  Pooler)
#
#  cls_dropout (TFDebertaV2St  multiple                  0
#  ableDropout)
#
#  classifier (Dense)          multiple                  26129
#
# =================================================================
# Total params: 547001873 (2.04 GB)
# Trainable params: 547001873 (2.04 GB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# alBERTina Model None

# %%
history=model.fit(X_train,y_train,batch_size=32,epochs=600,validation_data=(X_test,y_test),callbacks=callbacks)
# Out:
# Epoch 1/600
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/transformers/models/deberta_v2/modeling_tf_deberta_v2.py:125: Bernoulli.__init__ (from tensorflow.python.ops.distributions.bernoulli) is deprecated and will be removed after 2019-01-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.distributions`.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/distributions/bernoulli.py:86: Distribution.__init__ (from tensorflow.python.ops.distributions.distribution) is deprecated and will be removed after 2019-01-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.distributions`.
# 9/9 [==============================] - 101s 5s/step - loss: 2.8881 - accuracy: 0.0607 - val_loss: 2.8295 - val_accuracy: 0.1000
# Epoch 2/600
# 9/9 [==============================] - 11s 1s/step - loss: 2.8322 - accuracy: 0.0786 - val_loss: 2.8245 - val_accuracy: 0.1000
# Epoch 3/600
# 9/9 [==============================] - 11s 1s/step - loss: 2.8442 - accuracy: 0.0929 - val_loss: 2.8130 - val_accuracy: 0.1714
# Epoch 4/600
# 9/9 [==============================] - 11s 1s/step - loss: 2.7889 - accuracy: 0.1036 - val_loss: 2.7859 - val_accuracy: 0.1429
# Epoch 5/600
# 9/9 [==============================] - 5s 593ms/step - loss: 2.7388 - accuracy: 0.0964 - val_loss: 2.7924 - val_accuracy: 0.1143
# Epoch 6/600
# 9/9 [==============================] - 5s 591ms/step - loss: 2.7749 - accuracy: 0.1179 - val_loss: 2.7933 - val_accuracy: 0.1429
# Epoch 7/600
# 9/9 [==============================] - 5s 602ms/step - loss: 2.7843 - accuracy: 0.1429 - val_loss: 2.7993 - val_accuracy: 0.1286
# Epoch 8/600
# 9/9 [==============================] - 11s 1s/step - loss: 2.8210 - accuracy: 0.1107 - val_loss: 2.7782 - val_accuracy: 0.1714
# Epoch 9/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7956 - accuracy: 0.0821 - val_loss: 2.7774 - val_accuracy: 0.1429
# Epoch 10/600
# 9/9 [==============================] - 5s 583ms/step - loss: 2.7669 - accuracy: 0.0929 - val_loss: 2.7822 - val_accuracy: 0.1143
# Epoch 11/600
# 9/9 [==============================] - 11s 1s/step - loss: 2.7508 - accuracy: 0.1107 - val_loss: 2.7563 - val_accuracy: 0.1286
# Epoch 12/600
# 9/9 [==============================] - 11s 1s/step - loss: 2.7348 - accuracy: 0.1214 - val_loss: 2.7514 - val_accuracy: 0.1571
# Epoch 13/600
# 9/9 [==============================] - 11s 1s/step - loss: 2.7173 - accuracy: 0.1357 - val_loss: 2.7420 - val_accuracy: 0.1714
# Epoch 14/600
# 9/9 [==============================] - 5s 572ms/step - loss: 2.6825 - accuracy: 0.1071 - val_loss: 2.7644 - val_accuracy: 0.1429
# Epoch 15/600
# 9/9 [==============================] - 5s 565ms/step - loss: 2.6981 - accuracy: 0.1143 - val_loss: 2.7711 - val_accuracy: 0.1000
# Epoch 16/600
# 9/9 [==============================] - 5s 555ms/step - loss: 2.6903 - accuracy: 0.1286 - val_loss: 2.7676 - val_accuracy: 0.0857
# Epoch 17/600
# 9/9 [==============================] - 5s 578ms/step - loss: 2.7130 - accuracy: 0.1607 - val_loss: 2.7583 - val_accuracy: 0.1143
# Epoch 18/600
# 9/9 [==============================] - 5s 568ms/step - loss: 2.7005 - accuracy: 0.1071 - val_loss: 2.7593 - val_accuracy: 0.1143
# Epoch 19/600
# 9/9 [==============================] - 11s 1s/step - loss: 2.6379 - accuracy: 0.1571 - val_loss: 2.7352 - val_accuracy: 0.0857
# Epoch 20/600
# 9/9 [==============================] - 5s 558ms/step - loss: 2.6634 - accuracy: 0.1571 - val_loss: 2.7433 - val_accuracy: 0.0857
# Epoch 21/600
# 9/9 [==============================] - 5s 569ms/step - loss: 2.6661 - accuracy: 0.1286 - val_loss: 2.7395 - val_accuracy: 0.1143
# Epoch 22/600
# 9/9 [==============================] - 11s 1s/step - loss: 2
600
# 9/9 [==============================] - 5s 557ms/step - loss: 0.0327 - accuracy: 0.9857 - val_loss: 0.7193 - val_accuracy: 0.8714
# Epoch 203/600
# 9/9 [==============================] - 5s 559ms/step - loss: 0.0396 - accuracy: 0.9857 - val_loss: 0.6910 - val_accuracy: 0.8714
# Epoch 204/600
# 9/9 [==============================] - 5s 558ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.7627 - val_accuracy: 0.8286
# Epoch 205/600
# 9/9 [==============================] - 5s 555ms/step - loss: 0.0416 - accuracy: 0.9893 - val_loss: 0.4968 - val_accuracy: 0.9143
# Epoch 206/600
# 9/9 [==============================] - 5s 552ms/step - loss: 0.0437 - accuracy: 0.9857 - val_loss: 0.4773 - val_accuracy: 0.9143
# Epoch 207/600
# 9/9 [==============================] - 5s 556ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.4685 - val_accuracy: 0.9000
# Epoch 208/600
# 9/9 [==============================] - 5s 553ms/step - loss: 0.0065 - accuracy: 0.9964 - val_loss: 0.4458 - val_accuracy: 0.9000
# Epoch 209/600
# 9/9 [==============================] - 5s 554ms/step - loss: 0.0367 - accuracy: 0.9893 - val_loss: 0.3997 - val_accuracy: 0.9286
# Epoch 210/600
# 9/9 [==============================] - 5s 558ms/step - loss: 0.0400 - accuracy: 0.9893 - val_loss: 0.4701 - val_accuracy: 0.9000
# Epoch 211/600
# 9/9 [==============================] - 5s 554ms/step - loss: 0.0292 - accuracy: 0.9964 - val_loss: 0.8897 - val_accuracy: 0.8286
# Epoch 212/600
# 9/9 [==============================] - 5s 568ms/step - loss: 0.1245 - accuracy: 0.9643 - val_loss: 0.5097 - val_accuracy: 0.9000
# Epoch 213/600
# 9/9 [==============================] - 5s 554ms/step - loss: 0.1078 - accuracy: 0.9643 - val_loss: 0.5228 - val_accuracy: 0.9000
# Epoch 214/600
# 9/9 [==============================] - 5s 556ms/step - loss: 0.0279 - accuracy: 0.9929 - val_loss: 0.5159 - val_accuracy: 0.9000
# Epoch 215/600
# 9/9 [==============================] - 5s 559ms/step - loss: 0.0466 - accuracy: 0.9857 - val_loss: 0.3809 - val_accuracy: 0.9429
# Epoch 216/600
# 9/9 [==============================] - 5s 554ms/step - loss: 0.0604 - accuracy: 0.9857 - val_loss: 0.5273 - val_accuracy: 0.9000
# Epoch 217/600
# 9/9 [==============================] - 5s 555ms/step - loss: 0.0825 - accuracy: 0.9857 - val_loss: 0.4254 - val_accuracy: 0.9286
# Epoch 218/600
# 9/9 [==============================] - 5s 553ms/step - loss: 0.0242 - accuracy: 0.9857 - val_loss: 0.5784 - val_accuracy: 0.9143
# Epoch 219/600
# 9/9 [==============================] - 5s 553ms/step - loss: 0.0453 - accuracy: 0.9857 - val_loss: 0.7231 - val_accuracy: 0.8714
# Epoch 220/600
# 9/9 [==============================] - 5s 555ms/step - loss: 0.0377 - accuracy: 0.9929 - val_loss: 0.8481 - val_accuracy: 0.8429
# Epoch 221/600
# 9/9 [==============================] - 5s 554ms/step - loss: 0.0664 - accuracy: 0.9786 - val_loss: 0.5256 - val_accuracy: 0.9000
# Epoch 222/600
# 9/9 [==============================] - 5s 567ms/step - loss: 0.0232 - accuracy: 0.9893 - val_loss: 0.6094 - val_accuracy: 0.8714
# Epoch 223/600
# 9/9 [==============================] - 5s 554ms/step - loss: 0.0715 - accuracy: 0.9786 - val_loss: 0.5711 - val_accuracy: 0.8857
# Epoch 224/600
# 9/9 [==============================] - 5s 553ms/step - loss: 0.0492 - accuracy: 0.9893 - val_loss: 0.5055 - val_accuracy: 0.8429
# Epoch 225/600
# 9/9 [==============================] - 5s 556ms/step - loss: 0.0611 - accuracy: 0.9821 - val_loss: 0.3649 - val_accuracy: 0.8714
# Epoch 226/600
# 9/9 [==============================] - 5s 554ms/step - loss: 0.0173 - accuracy: 0.9964 - val_loss: 0.4610 - val_accuracy: 0.8714
# Epoch 227/600
# 9/9 [==============================] - 5s 554ms/step - loss: 0.0552 - accuracy: 0.9893 - val_loss: 0.3883 - val_accuracy: 0.9000
# Epoch 228/600
# 9/9 [==============================] - 24s 3s/step - loss: 0.0221 - accuracy: 0.9929 - val_loss: 0.2644 - val_accuracy: 0.9429
# Epoch 229/600
# 9/9 [==============================] - 11s 1s/step - loss: 0.0286 - accuracy: 0.9893 - val_loss: 0.2386 - val_accuracy: 0.9429
# Epoch 230/600
# 9/9 [==============================] - 5s 556ms/step - loss: 0.
600
# 9/9 [==============================] - 5s 555ms/step - loss: 0.0255 - accuracy: 0.9929 - val_loss: 0.3016 - val_accuracy: 0.9429
# Epoch 260/600
# 9/9 [==============================] - 5s 555ms/step - loss: 0.0127 - accuracy: 0.9964 - val_loss: 0.2464 - val_accuracy: 0.9429
# Epoch 261/600
# 9/9 [==============================] - 5s 555ms/step - loss: 0.0463 - accuracy: 0.9857 - val_loss: 0.2409 - val_accuracy: 0.9571
# Epoch 262/600
# 9/9 [==============================] - 5s 556ms/step - loss: 0.0351 - accuracy: 0.9893 - val_loss: 0.2551 - val_accuracy: 0.9571
# Epoch 263/600
# 9/9 [==============================] - 5s 555ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.2716 - val_accuracy: 0.9429
# Epoch 264/600
# 9/9 [==============================] - 5s 556ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.2882 - val_accuracy: 0.9429
# Epoch 265/600
# 9/9 [==============================] - 5s 553ms/step - loss: 0.0113 - accuracy: 0.9964 - val_loss: 0.3240 - val_accuracy: 0.9571
# Epoch 266/600
# 9/9 [==============================] - 5s 553ms/step - loss: 0.0313 - accuracy: 0.9893 - val_loss: 0.3348 - val_accuracy: 0.9571
# Epoch 267/600
# 9/9 [==============================] - 5s 555ms/step - loss: 0.0129 - accuracy: 0.9964 - val_loss: 0.3456 - val_accuracy: 0.9571
# Epoch 268/600
# 9/9 [==============================] - 5s 555ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.3494 - val_accuracy: 0.9571
# Epoch 269/600
# 9/9 [==============================] - 5s 555ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.3529 - val_accuracy: 0.9429
# Epoch 270/600
# 9/9 [==============================] - 5s 556ms/step - loss: 0.0143 - accuracy: 0.9964 - val_loss: 0.3601 - val_accuracy: 0.9429
# Epoch 271/600
# 9/9 [==============================] - 5s 558ms/step - loss: 0.0115 - accuracy: 0.9964 - val_loss: 0.3607 - val_accuracy: 0.9429
# Epoch 272/600
# 9/9 [==============================] - 5s 556ms/step - loss: 0.0119 - accuracy: 0.9964 - val_loss: 0.3616 - val_accuracy: 0.9429
# Epoch 273/600
# 9/9 [==============================] - 5s 555ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.3613 - val_accuracy: 0.9429
# Epoch 274/600
# 9/9 [==============================] - 5s 556ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.3588 - val_accuracy: 0.9429
# Epoch 275/600
# 9/9 [==============================] - 5s 556ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.3514 - val_accuracy: 0.9429
# Epoch 276/600
# 9/9 [==============================] - 5s 553ms/step - loss: 0.0334 - accuracy: 0.9964 - val_loss: 0.3349 - val_accuracy: 0.9429
# Epoch 277/600
# 9/9 [==============================] - 5s 556ms/step - loss: 0.0282 - accuracy: 0.9964 - val_loss: 0.3606 - val_accuracy: 0.9429
# Epoch 278/600
# 2/9 [=====>........................] - ETA: 3s - loss: 0.0022 - accuracy: 1.0000

# %%
with open('/content/drive/MyDrive/PECE/models/albertina_model_v4', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)
model.config.to_json_file('/content/drive/MyDrive/PECE/models/Config-alBERTina-fine-tuning_v4.json')

# %%
import keras
from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('alBERTina Fine-Tuning')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.savefig('/content/drive/MyDrive/PECE/models/alBERTina-fine-tuning.png')
model.config.to_json_file('/content/drive/MyDrive/PECE/models/Config-alBERTina-fine-tuning.json')

# %%
import json

# Convert and write JSON object to file
with open("/content/drive/MyDrive/PECE/resoucers/dict_classes.json", "w") as outfile:
    json.dump(dict_classes, outfile)

# %%
dict_classes = dict([i for i in zip(data['gt'].astype(str).values,data['label'].values)])
labels_dict = [dict_classes[str(i)] for i in [*range(len(list(dict_classes.keys())))]]

# %%
model_id = 'neuralmind/bert-base-portuguese-cased'
model_save_path='/content/drive/MyDrive/PECE/models/bertimbau_model.h5'

tokenizer = AutoTokenizer.from_pretrained(model_id)
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
metric = tf.keras.metrics.SparseCategoricalAccuracy('accuracy')
optimizer = tf.keras.optimizers.Adam(learning_rate=2e-5,epsilon=1e-08)

trained_model = TFBertForSequenceClassification.from_pretrained(model_id,num_labels=num_classes)
# trained_model.compile(loss=loss,optimizer=optimizer, metrics=[metric])
trained_model.load_weights(model_save_path)

preds = trained_model.predict([val_inp,val_mask],batch_size=1)
pred_labels = np.argmax(preds.logits, axis=1)
f1 = f1_score(val_label,pred_labels,average='micro')
print('F1 score',f1)
print('Classification Report')
print(classification_report(val_label,pred_labels,target_names=labels_dict))

print('Training and saving built model.....')

#FOCO NO RECALL > 80%
#APOS ISSO PRECISAO
# Out:
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# Some layers of TFBertForSequenceClassification were not initialized from the model checkpoint at neuralmind/bert-base-portuguese-cased and are newly initialized: ['classifier', 'bert/pooler/dense/bias:0', 'bert/pooler/dense/kernel:0']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 55/55 [==============================] - 4s 8ms/step
# F1 score 0.9090909090909091
# Classification Report
#                                      precision    recall  f1-score   support
#
#                CARGO_DO_FUNCIONARIO       1.00      1.00      1.00         5
#         DEPARTAMENTO_DO_FUNCIONARIO       1.00      1.00      1.00         4
#            INFORMACAO_SOBRE_CLIENTE       1.00      0.75      0.86         4
#                   LOCALIZAR_CLIENTE       0.67      1.00      0.80         2
#               LOCALIZAR_FUNCIONARIO       1.00      1.00      1.00         4
#    LOCALIZAR_PRODUTOS_PELA_PRODUCAO       0.75      1.00      0.86         3
#       LOCALIZAR_PRODUTOS_PELO_CUSTO       0.86      1.00      0.92         6
#       METRICAS_DE_CUSTO_DE_PRODUTOS       0.50      1.00      0.67         1
#    METRICAS_DE_PRODUCAO_DE_PRODUTOS       1.00      1.00      1.00         5
#  METRICAS_DE_PRODUTOS_POR_CATEGORIA       1.00      0.25      0.40         4
#               METRICAS_DOS_CLIENTES       0.86      1.00      0.92         6
#  METRICAS_DO_QUADRO_DE_FUNCIONARIOS       1.00      0.67      0.80         3
# MOVIMENTACAO_QUADRO_DE_FUNCIONARIOS       1.00      1.00      1.00         3
#         QUANTIDADE_DE_DEPARTAMENTOS       1.00      1.00      1.00         2
#           TEMPO_DE_CASA_FUNCIONARIO       1.00      1.00      1.00         3
#
#                            accuracy                           0.91        55
#                           macro avg       0.91      0.91      0.88        55
#                        weighted avg       0.93      0.91      0.90        55
#
# Training and saving built model.....

# %%
teste = "Quantos funcionarios tem no setor de marketing?"

# %%
input_ids=[]
attention_masks=[]

bert_inp=tokenizer.encode_plus(teste,add_special_tokens = True,max_length =64, pad_to_max_length = True,return_attention_mask = True)
input_ids.append(bert_inp['input_ids'])
attention_masks.append(bert_inp['attention_mask'])

input_ids=np.asarray(input_ids)
attention_masks=np.array(attention_masks)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2614: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(

# %%
preds = trained_model.predict([input_ids,attention_masks],batch_size=1)
# Out:
# 1/1 [==============================] - 0s 26ms/step

# %%
teste=np.where(preds.logits>=0.50,1,0)

# %%
preds.logits
# Out:
# array([[-1.7778617 , -0.53754526, -0.90348244, -0.8599582 ,  1.6856688 ,
#         -0.44356814, -0.70820117, -1.3051971 , -0.49319133, -0.8795275 ,
#          0.80512565,  5.828703  , -0.9201504 ,  2.0146732 , -0.72137386]],
#       dtype=float32)

# %%
for i,col in enumerate(teste[0]):
  if col == 1:
    print(dict_classes[i],preds.logits[0][i])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-97e05b19ed12> in <cell line: 1>()
#       1 for i,col in enumerate(teste[0]):
#       2   if col == 1:
# ----> 3     print(dict_classes[i],preds.logits[0][i])
#
# KeyError: 4

# %%
pred_labels = np.argmax(preds.logits, axis=1)

# %%
pred_labels
# Out:
# array([11])

# %%
guia = data.label.unique()

# %%
dict_classes[str(pred_labels[0])]
# Out:
# 'METRICAS_DO_QUADRO_DE_FUNCIONARIOS'
