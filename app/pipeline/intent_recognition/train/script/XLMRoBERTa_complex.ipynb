# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import pandas as pd
from sklearn.metrics import confusion_matrix,f1_score,classification_report
import numpy as np
import re,unicodedata,nltk
from transformers import AutoTokenizer, TFXLMRobertaForSequenceClassification, BertConfig
import keras
import pickle

# gpus = tf.config.list_physical_devices("GPU")
# if gpus:
#     for gpu in gpus:
#         print("Found a GPU with the name:", gpu)
# else:
#     print("Failed to detect a GPU.")

# %%
with open('/content/drive/MyDrive/PECE/models/dataset_train_test/dataset_dict.pickle', 'rb') as file:
    dataset_dict = pickle.load(file)

num_classes = dataset_dict['n_class']

# %%
model_id = 'xlm-roberta-large'
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = TFXLMRobertaForSequenceClassification.from_pretrained(model_id,num_labels=num_classes,hidden_dropout_prob=0.4)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/616 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFXLMRobertaForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFXLMRobertaForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.dense.weight', 'classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def applytokenizer(sentences):
  input_ids=[]
  attention_masks=[]

  for sent in sentences:
      bert_inp=tokenizer.encode_plus(sent,add_special_tokens = True,max_length = 64, padding='max_length',return_attention_mask = True)
      input_ids.append(bert_inp['input_ids'])
      attention_masks.append(bert_inp['attention_mask'])

  input_ids=np.asarray(input_ids)
  attention_masks=np.array(attention_masks)
  return [input_ids,attention_masks]

# %%
X_train = applytokenizer(dataset_dict['X_train'])
X_test = applytokenizer(dataset_dict['X_test'])
y_train = np.asarray(dataset_dict['y_train'])
y_test = np.asarray(dataset_dict['y_test'])

# %%
log_dir='/content/drive/MyDrive/PECE/tensorboard_data/tb_xlmroberta_v5_complex'
model_save_path='/content/drive/MyDrive/PECE/models/xlmroberta_model_v5_complex.h5'

callbacks = [
             keras.callbacks.ModelCheckpoint(filepath=model_save_path,save_weights_only=True,monitor='val_loss',mode='min',save_best_only=True),
             keras.callbacks.TensorBoard(log_dir=log_dir),
            keras.callbacks.EarlyStopping(monitor="val_loss",min_delta=0.01,patience=50,verbose=0,mode="min")
             ]

print('\nXLM-RoBERTa Model',model.summary())

loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
metric = tf.keras.metrics.SparseCategoricalAccuracy('accuracy')
optimizer = tf.keras.optimizers.Adam(learning_rate=2e-5,epsilon=1e-08)

model.compile(loss=loss,optimizer=optimizer,metrics=[metric])
# Out:
# Model: "tfxlm_roberta_for_sequence_classification"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  roberta (TFXLMRobertaMainL  multiple                  558840832
#  ayer)
#
#  classifier (TFXLMRobertaCl  multiple                  1067025
#  assificationHead)
#
# =================================================================
# Total params: 559907857 (2.09 GB)
# Trainable params: 559907857 (2.09 GB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# XLM-RoBERTa Model None

# %%
history=model.fit(X_train,y_train,batch_size=32,epochs=600,validation_data=(X_test,y_test),callbacks=callbacks)
# Out:
# Epoch 1/600
# 9/9 [==============================] - 127s 5s/step - loss: 2.9316 - accuracy: 0.0536 - val_loss: 2.8519 - val_accuracy: 0.0429
# Epoch 2/600
# 9/9 [==============================] - 22s 3s/step - loss: 2.8687 - accuracy: 0.0536 - val_loss: 2.8203 - val_accuracy: 0.0429
# Epoch 3/600
# 9/9 [==============================] - 19s 2s/step - loss: 2.8517 - accuracy: 0.0714 - val_loss: 2.7972 - val_accuracy: 0.0429
# Epoch 4/600
# 9/9 [==============================] - 24s 3s/step - loss: 2.8352 - accuracy: 0.0679 - val_loss: 2.7725 - val_accuracy: 0.0429
# Epoch 5/600
# 9/9 [==============================] - 20s 2s/step - loss: 2.8005 - accuracy: 0.0893 - val_loss: 2.7664 - val_accuracy: 0.1143
# Epoch 6/600
# 9/9 [==============================] - 20s 2s/step - loss: 2.7742 - accuracy: 0.1036 - val_loss: 2.7416 - val_accuracy: 0.1429
# Epoch 7/600
# 9/9 [==============================] - 21s 2s/step - loss: 2.7747 - accuracy: 0.1286 - val_loss: 2.7213 - val_accuracy: 0.1000
# Epoch 8/600
# 9/9 [==============================] - 13s 1s/step - loss: 2.7616 - accuracy: 0.1036 - val_loss: 2.7683 - val_accuracy: 0.0571
# Epoch 9/600
# 9/9 [==============================] - 13s 1s/step - loss: 2.7480 - accuracy: 0.0893 - val_loss: 2.7368 - val_accuracy: 0.1000
# Epoch 10/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7638 - accuracy: 0.0857 - val_loss: 2.7528 - val_accuracy: 0.1000
# Epoch 11/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7522 - accuracy: 0.1429 - val_loss: 2.7286 - val_accuracy: 0.0714
# Epoch 12/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7371 - accuracy: 0.1071 - val_loss: 2.7225 - val_accuracy: 0.1143
# Epoch 13/600
# 9/9 [==============================] - 34s 4s/step - loss: 2.7691 - accuracy: 0.1214 - val_loss: 2.7187 - val_accuracy: 0.0857
# Epoch 14/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7572 - accuracy: 0.1000 - val_loss: 2.7259 - val_accuracy: 0.1000
# Epoch 15/600
# 9/9 [==============================] - 13s 1s/step - loss: 2.7171 - accuracy: 0.1036 - val_loss: 2.7293 - val_accuracy: 0.0857
# Epoch 16/600
# 9/9 [==============================] - 22s 3s/step - loss: 2.7355 - accuracy: 0.1143 - val_loss: 2.7125 - val_accuracy: 0.1000
# Epoch 17/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7070 - accuracy: 0.1357 - val_loss: 2.7441 - val_accuracy: 0.1143
# Epoch 18/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7369 - accuracy: 0.0679 - val_loss: 2.7439 - val_accuracy: 0.0857
# Epoch 19/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7283 - accuracy: 0.0929 - val_loss: 2.7526 - val_accuracy: 0.0714
# Epoch 20/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7441 - accuracy: 0.1000 - val_loss: 2.7690 - val_accuracy: 0.0571
# Epoch 21/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7410 - accuracy: 0.0929 - val_loss: 2.7449 - val_accuracy: 0.1000
# Epoch 22/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7509 - accuracy: 0.1071 - val_loss: 2.7302 - val_accuracy: 0.1000
# Epoch 23/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7517 - accuracy: 0.0964 - val_loss: 2.7145 - val_accuracy: 0.0429
# Epoch 24/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7569 - accuracy: 0.0893 - val_loss: 2.7145 - val_accuracy: 0.1143
# Epoch 25/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7436 - accuracy: 0.1071 - val_loss: 2.7149 - val_accuracy: 0.1000
# Epoch 26/600
# 9/9 [==============================] - 28s 3s/step - loss: 2.7074 - accuracy: 0.1179 - val_loss: 2.7090 - val_accuracy: 0.1000
# Epoch 27/600
# 9/9 [==============================] - 21s 2s/step - loss: 2.7367 - accuracy: 0.1143 - val_loss: 2.7019 - val_accuracy: 0.1143
# Epoch 28/600
# 9/9 [==============================] - 24s 3s/step - loss: 2.7462 - accuracy: 0.0893 - val_loss: 2.6956 - val_accuracy: 0.0714
# Epoch 29/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7185 - accuracy: 0.1214 - val_loss: 2.6987 - val_accuracy: 0.1429
# Epoch 30/600
# 9/9 [==============================] - 13s 1s/step - loss: 2.7162 - accuracy: 0.1071 - val_loss: 2.7013 - val_accuracy: 0.2000
# Epoch 31/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7474 - accuracy: 0.1143 - val_loss: 2.7049 - val_accuracy: 0.1000
# Epoch 32/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.6975 - accuracy: 0.1179 - val_loss: 2.7060 - val_accuracy: 0.1000
# Epoch 33/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7341 - accuracy: 0.1036 - val_loss: 2.7138 - val_accuracy: 0.1143
# Epoch 34/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7395 - accuracy: 0.1071 - val_loss: 2.7124 - val_accuracy: 0.0714
# Epoch 35/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.6996 - accuracy: 0.1107 - val_loss: 2.7151 - val_accuracy: 0.0857
# Epoch 36/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.6827 - accuracy: 0.1250 - val_loss: 2.7192 - val_accuracy: 0.1143
# Epoch 37/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7261 - accuracy: 0.1036 - val_loss: 2.7144 - val_accuracy: 0.0857
# Epoch 38/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7167 - accuracy: 0.1143 - val_loss: 2.7084 - val_accuracy: 0.1000
# Epoch 39/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7322 - accuracy: 0.1036 - val_loss: 2.7069 - val_accuracy: 0.1571
# Epoch 40/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7126 - accuracy: 0.0964 - val_loss: 2.7067 - val_accuracy: 0.1143
# Epoch 41/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7571 - accuracy: 0.0857 - val_loss: 2.7090 - val_accuracy: 0.1000
# Epoch 42/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7359 - accuracy: 0.1214 - val_loss: 2.7098 - val_accuracy: 0.1286
# Epoch 43/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7173 - accuracy: 0.1107 - val_loss: 2.7093 - val_accuracy: 0.1143
# Epoch 44/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7270 - accuracy: 0.0857 - val_loss: 2.7098 - val_accuracy: 0.1143
# Epoch 45/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7165 - accuracy: 0.0929 - val_loss: 2.7121 - val_accuracy: 0.1000
# Epoch 46/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7496 - accuracy: 0.1357 - val_loss: 2.7099 - val_accuracy: 0.1000
# Epoch 47/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7261 - accuracy: 0.1000 - val_loss: 2.7069 - val_accuracy: 0.1000
# Epoch 48/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7489 - accuracy: 0.0857 - val_loss: 2.7049 - val_accuracy: 0.1000
# Epoch 49/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7507 - accuracy: 0.1036 - val_loss: 2.7036 - val_accuracy: 0.1000
# Epoch 50/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7320 - accuracy: 0.0929 - val_loss: 2.7026 - val_accuracy: 0.1000
# Epoch 51/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7252 - accuracy: 0.0893 - val_loss: 2.7024 - val_accuracy: 0.1000
# Epoch 52/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7238 - accuracy: 0.1107 - val_loss: 2.7017 - val_accuracy: 0.1000
# Epoch 53/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7179 - accuracy: 0.1214 - val_loss: 2.7025 - val_accuracy: 0.1000
# Epoch 54/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7129 - accuracy: 0.1214 - val_loss: 2.7041 - val_accuracy: 0.1000
# Epoch 55/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7545 - accuracy: 0.0964 - val_loss: 2.7044 - val_accuracy: 0.1000
# Epoch 56/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7592 - accuracy: 0.0857 - val_loss: 2.7044 - val_accuracy: 0.0857
# Epoch 57/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.6899 - accuracy: 0.1321 - val_loss: 2.7040 - val_accuracy: 0.0857
# Epoch 58/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7275 - accuracy: 0.1179 - val_loss: 2.6965 - val_accuracy: 0.1000
# Epoch 59/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7385 - accuracy: 0.0929 - val_loss: 2.7010 - val_accuracy: 0.1143
# Epoch 60/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7476 - accuracy: 0.1143 - val_loss: 2.6993 - val_accuracy: 0.1143
# Epoch 61/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7071 - accuracy: 0.0750 - val_loss: 2.6962 - val_accuracy: 0.1143
# Epoch 62/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7288 - accuracy: 0.1036 - val_loss: 2.7002 - val_accuracy: 0.1286
# Epoch 63/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7277 - accuracy: 0.1179 - val_loss: 2.7032 - val_accuracy: 0.1286
# Epoch 64/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7171 - accuracy: 0.1464 - val_loss: 2.7113 - val_accuracy: 0.1000
# Epoch 65/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7049 - accuracy: 0.1250 - val_loss: 2.7164 - val_accuracy: 0.1429
# Epoch 66/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7273 - accuracy: 0.0857 - val_loss: 2.7241 - val_accuracy: 0.1000
# Epoch 67/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7364 - accuracy: 0.0821 - val_loss: 2.7113 - val_accuracy: 0.1429
# Epoch 68/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7308 - accuracy: 0.0893 - val_loss: 2.7033 - val_accuracy: 0.1000
# Epoch 69/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7081 - accuracy: 0.0964 - val_loss: 2.7040 - val_accuracy: 0.1000
# Epoch 70/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7631 - accuracy: 0.1036 - val_loss: 2.7062 - val_accuracy: 0.1429
# Epoch 71/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7323 - accuracy: 0.1214 - val_loss: 2.7142 - val_accuracy: 0.1286
# Epoch 72/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7364 - accuracy: 0.1143 - val_loss: 2.7090 - val_accuracy: 0.1143
# Epoch 73/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.6886 - accuracy: 0.1321 - val_loss: 2.7036 - val_accuracy: 0.1143
# Epoch 74/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7087 - accuracy: 0.0929 - val_loss: 2.6988 - val_accuracy: 0.1000
# Epoch 75/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7232 - accuracy: 0.1036 - val_loss: 2.6989 - val_accuracy: 0.1000
# Epoch 76/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7410 - accuracy: 0.0821 - val_loss: 2.7017 - val_accuracy: 0.1000
# Epoch 77/600
# 9/9 [==============================] - 12s 1s/step - loss: 2.7200 - accuracy: 0.1179 - val_loss: 2.7015 - val_accuracy: 0.1000
# Epoch 78/600
# 3/9 [=========>....................] - ETA: 7s - loss: 2.6620 - accuracy: 0.0833

# %%
with open('/content/drive/MyDrive/PECE/models/xlmroberta_model_v5_complex', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)
model.config.to_json_file('/content/drive/MyDrive/PECE/models/Config-XLM-RoBERTa-fine-tuning_v5_complex.json')

# %%
import keras
from matplotlib import pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('XLM-RoBERTa Fine-Tuning')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.savefig('/content/drive/MyDrive/PECE/models/XLM-RoBERTa-fine-tuning_v5.png')
model.config.to_json_file('/content/drive/MyDrive/PECE/models/Config-XLM-RoBERTa-fine-tuning_v5.json')

# %%
import json

# Convert and write JSON object to file
with open("/content/drive/MyDrive/PECE/resoucers/dict_classes.json", "w") as outfile:
    json.dump(dict_classes, outfile)

# %%
dict_classes = dict([i for i in zip(data['gt'].astype(str).values,data['label'].values)])
labels_dict = [dict_classes[str(i)] for i in [*range(len(list(dict_classes.keys())))]]

# %%
model_id = 'neuralmind/bert-base-portuguese-cased'
model_save_path='/content/drive/MyDrive/PECE/models/bertimbau_model.h5'

tokenizer = AutoTokenizer.from_pretrained(model_id)
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
metric = tf.keras.metrics.SparseCategoricalAccuracy('accuracy')
optimizer = tf.keras.optimizers.Adam(learning_rate=2e-5,epsilon=1e-08)

trained_model = TFBertForSequenceClassification.from_pretrained(model_id,num_labels=num_classes)
# trained_model.compile(loss=loss,optimizer=optimizer, metrics=[metric])
trained_model.load_weights(model_save_path)

preds = trained_model.predict([val_inp,val_mask],batch_size=1)
pred_labels = np.argmax(preds.logits, axis=1)
f1 = f1_score(val_label,pred_labels,average='micro')
print('F1 score',f1)
print('Classification Report')
print(classification_report(val_label,pred_labels,target_names=labels_dict))

print('Training and saving built model.....')

#FOCO NO RECALL > 80%
#APOS ISSO PRECISAO
# Out:
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# Some layers of TFBertForSequenceClassification were not initialized from the model checkpoint at neuralmind/bert-base-portuguese-cased and are newly initialized: ['classifier', 'bert/pooler/dense/bias:0', 'bert/pooler/dense/kernel:0']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 55/55 [==============================] - 4s 8ms/step
# F1 score 0.9090909090909091
# Classification Report
#                                      precision    recall  f1-score   support
#
#                CARGO_DO_FUNCIONARIO       1.00      1.00      1.00         5
#         DEPARTAMENTO_DO_FUNCIONARIO       1.00      1.00      1.00         4
#            INFORMACAO_SOBRE_CLIENTE       1.00      0.75      0.86         4
#                   LOCALIZAR_CLIENTE       0.67      1.00      0.80         2
#               LOCALIZAR_FUNCIONARIO       1.00      1.00      1.00         4
#    LOCALIZAR_PRODUTOS_PELA_PRODUCAO       0.75      1.00      0.86         3
#       LOCALIZAR_PRODUTOS_PELO_CUSTO       0.86      1.00      0.92         6
#       METRICAS_DE_CUSTO_DE_PRODUTOS       0.50      1.00      0.67         1
#    METRICAS_DE_PRODUCAO_DE_PRODUTOS       1.00      1.00      1.00         5
#  METRICAS_DE_PRODUTOS_POR_CATEGORIA       1.00      0.25      0.40         4
#               METRICAS_DOS_CLIENTES       0.86      1.00      0.92         6
#  METRICAS_DO_QUADRO_DE_FUNCIONARIOS       1.00      0.67      0.80         3
# MOVIMENTACAO_QUADRO_DE_FUNCIONARIOS       1.00      1.00      1.00         3
#         QUANTIDADE_DE_DEPARTAMENTOS       1.00      1.00      1.00         2
#           TEMPO_DE_CASA_FUNCIONARIO       1.00      1.00      1.00         3
#
#                            accuracy                           0.91        55
#                           macro avg       0.91      0.91      0.88        55
#                        weighted avg       0.93      0.91      0.90        55
#
# Training and saving built model.....

# %%
teste = "Quantos funcionarios tem no setor de marketing?"

# %%
input_ids=[]
attention_masks=[]

bert_inp=tokenizer.encode_plus(teste,add_special_tokens = True,max_length =64, pad_to_max_length = True,return_attention_mask = True)
input_ids.append(bert_inp['input_ids'])
attention_masks.append(bert_inp['attention_mask'])

input_ids=np.asarray(input_ids)
attention_masks=np.array(attention_masks)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2614: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(

# %%
preds = trained_model.predict([input_ids,attention_masks],batch_size=1)
# Out:
# 1/1 [==============================] - 0s 26ms/step

# %%
teste=np.where(preds.logits>=0.50,1,0)

# %%
preds.logits
# Out:
# array([[-1.7778617 , -0.53754526, -0.90348244, -0.8599582 ,  1.6856688 ,
#         -0.44356814, -0.70820117, -1.3051971 , -0.49319133, -0.8795275 ,
#          0.80512565,  5.828703  , -0.9201504 ,  2.0146732 , -0.72137386]],
#       dtype=float32)

# %%
for i,col in enumerate(teste[0]):
  if col == 1:
    print(dict_classes[i],preds.logits[0][i])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-97e05b19ed12> in <cell line: 1>()
#       1 for i,col in enumerate(teste[0]):
#       2   if col == 1:
# ----> 3     print(dict_classes[i],preds.logits[0][i])
#
# KeyError: 4

# %%
pred_labels = np.argmax(preds.logits, axis=1)

# %%
pred_labels
# Out:
# array([11])

# %%
guia = data.label.unique()

# %%
dict_classes[str(pred_labels[0])]
# Out:
# 'METRICAS_DO_QUADRO_DE_FUNCIONARIOS'
